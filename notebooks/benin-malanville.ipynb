# %% [markdown]
# Import Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import windrose
from scipy.stats import zscore
from windrose import WindroseAxes
from scipy import stats
import os

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('../data/benin-malanville.csv', parse_dates=['Timestamp'])

# %% [markdown]
# # Summary Statistics

# %%
print(f"\n📍 Benin")
    
# Summary stats
print("\n📊 Summary Statistics:")
display(df.describe())
# Out:
# 📍 Benin
#
# 📊 Summary Statistics:
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-02-07 12:00:30.000000512     240.559452     167.187516
# min              2021-08-09 00:01:00     -12.900000      -7.800000
# 25%              2021-11-08 06:00:45      -2.000000      -0.500000
# 50%              2022-02-07 12:00:30       1.800000      -0.100000
# 75%              2022-05-09 18:00:15     483.400000     314.200000
# max              2022-08-09 00:00:00    1413.000000     952.300000
# std                              NaN     331.131327     261.710501
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      115.358961     236.589496     228.883576      28.179683
# min       -12.600000       0.000000       0.000000      11.000000
# 25%        -2.100000       0.000000       0.000000      24.200000
# 50%         1.600000       4.500000       4.300000      28.000000
# 75%       216.300000     463.700000     447.900000      32.300000
# max       759.200000    1342.300000    1342.300000      43.800000
# std       158.691074     326.894859     316.536515       5.924297
#
#                   RH             WS         WSgust        WSstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       54.487969       2.121113       2.809195       0.473390
# min         2.100000       0.000000       0.000000       0.000000
# 25%        28.800000       1.000000       1.300000       0.400000
# 50%        55.100000       1.900000       2.600000       0.500000
# 75%        80.100000       3.100000       4.100000       0.600000
# max       100.000000      19.500000      26.600000       4.200000
# std        28.073069       1.603466       2.029120       0.273395
#
#                   WD        WDstdev             BP       Cleaning  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      153.435172       8.582407     994.197199       0.000923
# min         0.000000       0.000000     985.000000       0.000000
# 25%        59.000000       3.700000     993.000000       0.000000
# 50%       181.000000       8.600000     994.000000       0.000000
# 75%       235.100000      12.300000     996.000000       0.000000
# max       360.000000      99.400000    1003.000000       1.000000
# std       102.332842       6.385864       2.474993       0.030363
#
#        Precipitation          TModA          TModB  Comments
# count  525600.000000  525600.000000  525600.000000       0.0
# mean        0.001905      35.246026      32.471736       NaN
# min         0.000000       9.000000       8.100000       NaN
# 25%         0.000000      24.200000      23.600000       NaN
# 50%         0.000000      30.000000      28.900000       NaN
# 75%         0.000000      46.900000      41.500000       NaN
# max         2.500000      81.000000      72.500000       NaN
# std         0.037115      14.807258      12.348743       NaN

# %% [markdown]
# # Missing value detection and handling

# %%
print("\n❓ Missing Value Count:")
missing = df.isna().sum()
display(missing[missing > 0])

# Identify columns with >5% missing values
total = len(df)
high_nulls = missing[missing > 0][missing / total > 0.05]
if not high_nulls.empty:
    print("\n⚠️ Columns with >5% missing values:")
    display(high_nulls)
else:
    print("\n✅ No columns with >5% missing values.")
# Out:
# ❓ Missing Value Count:
# Comments    525600
# dtype: int64
# ⚠️ Columns with >5% missing values:
# Comments    525600
# dtype: int64

# %% [markdown]
# # Outlier Detection(Z-score) and Basic cleaning

# %%
columns_to_check = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']

# Check and handle missing values in key columns
missing_before = df[columns_to_check].isnull().sum()
print("Missing before imputation:\n", missing_before)


#drop column once we run this code we comment this out
# null_col = df['Comments'].isna().all()
# print(f"Is comments null?{null_col}")
# df.drop(columns=["Comments"], inplace=True)


# Impute missing values using median
for col in columns_to_check:
    df[col] = df[col].fillna(df[col].median())

#Compute Z-scores
z_scores = df[columns_to_check].apply(zscore)

#Identify rows with any z-score > 3 (or < -3)
outliers = (z_scores.abs() > 3).any(axis=1)
print(f"Outliers detected: {outliers.sum()} rows")

# Remove outlier rows
df_cleaned = df[~outliers].copy()

#Final check
print(f"Cleaned shape: {df_cleaned.shape}")

#Save cleaned data
os.makedirs('data', exist_ok=True)
df_cleaned.to_csv(f"../data/benin-malanville_clean.csv", index=False)

print(f"benin-malanville_clean.csv saved.\n")
# Out:
# Missing before imputation:
#  GHI       0
# DNI       0
# DHI       0
# ModA      0
# ModB      0
# WS        0
# WSgust    0
# dtype: int64
# Outliers detected: 7740 rows
# Cleaned shape: (517860, 19)
# benin-malanville_clean.csv saved.

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# # Load the cleaned csv

# %%
df = pd.read_csv("../data/benin-malanville_clean.csv", parse_dates=['Timestamp'])

# Ensure Timestamp is datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Create time-based columns
df['Month'] = df['Timestamp'].dt.month
df['Hour'] = df['Timestamp'].dt.hour

# %% [markdown]
# # Daily Trend Plot Hourly Mean

# %%
hourly_mean = df.groupby('Hour')[['GHI', 'DNI', 'DHI', 'Tamb']].mean()

plt.figure(figsize=(12, 6))
plt.plot(hourly_mean)
plt.title("Benin - Melanville - Average Values by Hour of Day")
plt.xlabel("Hour")
plt.ylabel("Value")
plt.legend(['GHI', 'DNI', 'DHI', 'Tamb'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Monthly Trend Plot

# %%
monthly_mean = df.groupby('Month')[['GHI', 'DNI', 'DHI', 'Tamb']].mean()

monthly_mean.plot(kind='bar', figsize=(12, 6))
plt.title("Benin - Melanville - Monthly Average")
plt.xlabel("Month")
plt.ylabel("Value")
plt.grid(True)
plt.legend(['GHI', 'DNI', 'DHI', 'Tamb'])
plt.show()

# %% [markdown]
# # Identifying Anomalies

# %%
df.set_index('Timestamp')[['GHI', 'DNI', 'DHI', 'Tamb']].plot(figsize=(15, 6), alpha=0.5)
plt.title("Benin - Melanville - Time Series of GHI, DNI, DHI, Tamb")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %% [markdown]
# # Impact of Cleaning

# %%
# Example for one city, repeat for all three
df = pd.read_csv("data/benin-malanville_clean.csv")

cleaning_impact = df.groupby('Cleaning')[['ModA', 'ModB']].mean()
print(cleaning_impact)
# Out:
#                 ModA       ModB
# Cleaning
# 0         232.323881  224.95509
# 1         306.610124  301.45000

# %% [markdown]
# # Plotting a comparison

# %%
cleaning_impact.plot(kind='bar', figsize=(8, 5), color=['skyblue', 'orange'])
plt.title("Average ModA & ModB Before and After Cleaning")
plt.xlabel("Cleaning (0 = Before, 1 = After)")
plt.ylabel("Average Sensor Output")
plt.xticks(rotation=0)
plt.grid(True)
plt.legend(["ModA", "ModB"])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation & Relationship Analysis

# %%
df = pd.read_csv("data/benin-malanville_clean.csv")

# Subset of relevant columns
columns = ['GHI', 'DNI', 'DHI', 'TModA', 'TModB']
correlation_matrix = df[columns].corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scatter plots

# %%
sns.scatterplot(data=df, x='WS', y='GHI')
plt.title('Wind Speed vs. GHI')
plt.show()

# %%
sns.scatterplot(data=df, x='WSgust', y='GHI')
plt.title('Wind Gust vs. GHI')
plt.show()

# %%
sns.scatterplot(data=df, x='WD', y='GHI')
plt.title('Wind Direction vs. GHI')
plt.show()

# %%
sns.scatterplot(data=df, x='RH', y='Tamb')
plt.title('RH vs. Ambient Temperature')
plt.show()

# %%
sns.scatterplot(data=df, x='RH', y='GHI')
plt.title('RH vs. GHI')
plt.show()

# %% [markdown]
# # Wind & Distribution Analysis

# %%
ws = df['WS']
wd = df['WD']

ax = WindroseAxes.from_ax()
ax.bar(wd, ws, normed=True, opening=0.8, edgecolor='white')
ax.set_legend()
plt.title("Benin - Melanville - Wind Rose")
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(df['GHI'], bins=30, color='orange')
plt.title("Benin - Melanville - GHI Distribution")
plt.xlabel("GHI (W/m²)")
plt.ylabel("Frequency")

# WS
plt.subplot(1, 2, 2)
plt.hist(df['WS'], bins=30, color='skyblue')
plt.title("Benin - Melanville - Wind Speed Distribution")
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Temprature analysis

# %%
sns.scatterplot(data=df, x='RH', y='Tamb')
sns.scatterplot(data=df, x='RH', y='GHI')
# Out:
# <Axes: xlabel='RH', ylabel='Tamb'>

# %% [markdown]
# # Bubble Chart

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='Tamb', y='GHI',
    size='RH',  # or 'BP'
    hue='RH',
    palette='viridis',
    sizes=(10, 200),
    alpha=0.6
)
plt.title('GHI vs. Tamb with RH Bubble Size')
# Out:
# Text(0.5, 1.0, 'GHI vs. Tamb with RH Bubble Size')
# /home/eyuleo/Desktop/solar-challenge-we/.venv/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/eyuleo/Desktop/solar-challenge-we/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
